# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# printing graph
def comparativeBar(include=["cpu"], color=['red'], width=0.35, title="Comparative", ld={'cpu':20}):
    # graph param load
    itms = len(include)
    ind = np.arange(itms)
    plt.axes([0, 0.6, 2, 2])
    leg = list(ld.keys())

    # incrementing width
    incWidth = -width
    xtimes=0

    # data access
    # reset temp buf
    load = []

    # seeking data
    for keyy, eachh in ld.items():
        if keyy in include:
            load.append(np.array(eachh))

    # prepping plot section
    incWidth += width
    xtimes += 1
    plt.bar(ind+incWidth, load, width, label='test')

    plt.ylabel('Charge MicroAh')
    plt.title(title)
    plt.grid(True)

    plt.xticks(ind + incWidth / xtimes, include)
    plt.legend(loc='best')
    plt.show()
    
#data filter
def dataFilter(data=None, cols=None):
    # target questions
    qs = ['Q1.', 'Q3.', 'Q7.', 'Q8.', 'Q10.']

    # buffer question of interest
    buf = []

    # column heads
    for each in qs:
        #get questions of interest in the distribution
        for eachh in cols:
            if each in eachh:
                buf.append(eachh)

    # get unique divisions per group
    dist = {}
    for each in buf:
        # discover groups per question
        if each not in dist.keys():
            dist[each] = {}
            tmp = data[each].unique().tolist()

            # pass tmp as keys
            for group in tmp:
                dist[each][group] = data.loc[data[each] == group, each].count()

    return dist

# %%
#smilarity measure
import math
import operator

def op(st=None, st1=None, rate=0.6):
    if st is not None and st1 is not None:
        st = st.lower()
        st1 = st1.lower()
        
        if len(st) > len(st1):
            sh = st1
            lo = st
        else:
            sh = st
            lo = st1
            
        #processing comparison
        found = 0
        count = 0
        miss = 0
        for each in lo:
            if count is len(sh): break
            if each is sh[count]:
                found += 1
                count += 1
            else:
                miss += 1
            
        #print (sh, '=>', lo)
        #print (found, miss, len(sh))
        #score = found/miss
        #print ('score %f' %(score))
        # print (math.log(score))
        # scaled score
        sscore = found/len(sh)
        #print ('ratio ', sscore)
        #print ('_\n')
        
        #return true if scaled score is > (0.6)~ rate
        if sscore > rate:
            return True
        else:
            return False
    else:
        print('Invalid inputs')

# %%
data = pd.read_excel('data.xlsx')

# %%
data.head()
# Out:
#                 Timestamp  \
# 0 2019-10-15 07:45:12.875
# 1 2019-10-16 05:46:07.513
# 2 2019-10-16 06:10:13.426
# 3 2019-10-16 06:14:36.755
# 4 2019-10-16 06:31:06.885
#
#   Q1. Please choose the closest market region that applies to you?  \
# 0                                             Africa
# 1                                             Africa
# 2                                               Asia
# 3                                             Africa
# 4                                             Africa
#
#    Q2. How many devices do you acquire mobile data for?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  4
#
#   Q3. What is your primary reason for acquiring mobile data?  \
# 0                                   General Browsing
# 1                                       Social Media
# 2  Utility Apps i.e Mobile Banking, Online Shoppi...
# 3                                   General Browsing
# 4                                   General Browsing
#
#    Q4. Roughly how many apps are most used on your device(s)?  \
# 0                                                  9
# 1                                                  6
# 2                                                  7
# 3                                                  5
# 4                                                  3
#
#    Q5. How many of those Apps are Utility Apps such as Mobile Banking, Online shopping?  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  0
#
#   Q6. Please list some of the Utility Apps, for the previous question Q5, that you frequently use? Try to rank them starting with the most important.  \
# 0                             Safaricom app, kcb app
# 1     Whatsapp \nGmail \nInstagram \nJumia\nCBA LOOP
# 2                                                NaN
# 3                        Banking App, Programming up
# 4                                               None
#
#   Q7. How often do you reload/renew your mobile data plan?  \
# 0                                          Irregular
# 1                                            Monthly
# 2                                            Monthly
# 3                                              Daily
# 4                                            Monthly
#
#   Q8. Select the Quantity of data mostly acquire for the period selected in the previous question, Q7?  \
# 0                                         1GB to 3GB
# 1                                           Over 5GB
# 2                                           Over 5GB
# 3                                         1GB to 3GB
# 4                                           Over 5GB
#
#    Q9. How long in days does the acquired data bundle roughly last i.e. before depletion?  \
# 0                                               28.0
# 1                                               21.0
# 2                                               30.0
# 3                                                1.0
# 4                                               27.0
#
#   Q10. How long does it take before reloading your mobile data plan after depletion?
# 0                                       Several Days
# 1                           Automatic reload 0 hours
# 2                                        A few Hours
# 3                           Automatic reload 0 hours
# 4                                       Several Days

# %%
cols = data.columns

# %%
for each in cols:
    print(each)
    print (data.loc[data[cols[1]] == "Africa", each])
    break
# Out:
# Timestamp
# 0     2019-10-15 07:45:12.875
# 1     2019-10-16 05:46:07.513
# 3     2019-10-16 06:14:36.755
# 4     2019-10-16 06:31:06.885
# 5     2019-10-16 06:48:37.714
# 6     2019-10-16 06:55:05.328
# 7     2019-10-16 07:56:39.648
# 9     2019-10-16 08:57:11.852
# 10    2019-10-16 09:05:33.466
# 11    2019-10-16 09:11:16.144
# 12    2019-10-16 09:15:58.534
# 13    2019-10-16 09:24:52.337
# 14    2019-10-16 09:32:22.862
# 16    2019-10-16 10:10:37.861
# 17    2019-10-16 10:18:43.596
# 21    2019-10-16 13:05:44.633
# 23    2019-10-16 15:09:54.650
# 24    2019-10-16 16:24:48.762
# 26    2019-10-16 21:46:25.285
# 29    2019-10-17 05:10:22.950
# 36    2019-10-17 05:50:28.726
# 37    2019-10-17 06:07:38.992
# 38    2019-10-17 06:19:40.008
# 39    2019-10-17 06:20:00.100
# 40    2019-10-17 06:21:07.077
# 41    2019-10-17 06:22:23.094
# 42    2019-10-17 06:27:06.671
# 44    2019-10-17 06:29:31.467
# 45    2019-10-17 06:32:25.013
# 46    2019-10-17 06:36:06.663
#                 ...
# 104   2019-10-17 18:35:37.345
# 105   2019-10-17 18:43:15.329
# 106   2019-10-17 19:24:58.238
# 107   2019-10-17 20:05:47.453
# 108   2019-10-17 20:24:32.592
# 109   2019-10-17 20:33:08.149
# 111   2019-10-18 02:11:25.100
# 114   2019-10-18 09:31:09.651
# 115   2019-10-18 12:54:56.646
# 116   2019-10-18 13:06:48.173
# 117   2019-10-18 13:12:19.517
# 118   2019-10-18 13:20:38.567
# 119   2019-10-18 13:23:45.954
# 120   2019-10-18 13:28:06.831
# 121   2019-10-18 13:28:08.351
# 122   2019-10-18 13:30:23.105
# 123   2019-10-18 14:14:27.870
# 124   2019-10-18 14:28:54.744
# 126   2019-10-18 16:21:42.917
# 127   2019-10-18 17:34:47.103
# 129   2019-10-18 17:56:58.048
# 130   2019-10-18 20:54:19.434
# 131   2019-10-19 07:10:09.475
# 132   2019-10-19 12:00:40.681
# 133   2019-10-19 15:29:19.251
# 134   2019-10-19 20:01:05.452
# 135   2019-10-20 05:59:27.554
# 136   2019-10-20 12:47:27.658
# 137   2019-10-21 13:55:53.135
# 138   2019-10-21 14:17:30.357
# Name: Timestamp, Length: 108, dtype: datetime64[ns]

# %%
print (cols[1])
data.loc[data[cols[1]] == "Africa", each].iloc[4]
# Out:
# Q1. Please choose the closest market region that applies to you?
# Timestamp('2019-10-16 06:48:37.714000')

# %%
data.loc[data[cols[1]] == "Africa", each].count()
# Out:
# 108

# %%
# target questions
qs = ['Q1.', 'Q3.', 'Q7.', 'Q8.', 'Q10.']

# buffer question of interest
buf = []

# column heads
for each in qs:
    #get questions of interest in the distribution
    for eachh in cols:
        if each in eachh:
            buf.append(eachh)

# get unique divisions per group
dist = {}
for each in buf:
    # discover groups per question
    if each not in dist.keys():
        dist[each] = {}
        tmp = data[each].unique().tolist()
        
        # pass tmp as keys
        for group in tmp:
            dist[each][group] = data.loc[data[each] == group, each].count()

dist
# Out:
# {'Q1. Please choose the closest market region that applies to you?': {'Africa': 108,
#   'Asia': 16,
#   'European Union': 12,
#   'Middle East': 1,
#   'East Europe': 1,
#   'North America': 1},
#  'Q3. What is your primary reason for acquiring mobile data?': {'General Browsing': 88,
#   'Social Media': 31,
#   'Utility Apps i.e Mobile Banking, Online Shopping, etc': 20},
#  'Q7. How often do you reload/renew your mobile data plan?': {'Irregular': 16,
#   'Monthly': 53,
#   'Daily': 57,
#   'Weekly': 13},
#  'Q8. Select the Quantity of data mostly acquire for the period selected in the previous question, Q7?': {'1GB to 3GB': 39,
#   'Over 5GB': 30,
#   '100MB to 250MB': 14,
#   'Less than 100MB': 17,
#   '250MB to 500MB': 14,
#   '500MB to 1GB': 18,
#   '3GB to 5GB': 7},
#  'Q10. How long does it take before reloading your mobile data plan after depletion?': {'Several Days': 23,
#   'Automatic reload 0 hours': 39,
#   'A few Hours': 40,
#   'A day': 37}}

# %%
#bar graph output
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# implementing a bar function
def comp(labels=('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp'), data=[10,8,6,4,2,1], title='', unit='usage'):
    #objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
    # labels
    objects = labels
    y_pos = np.arange(len(objects))
    
    #data
    performance = data

    plt.axes([0, 0.6, 1, 1])
    plt.bar(y_pos, performance, align='center', alpha=0.5, color='green')
    plt.xticks(y_pos, objects)

    # units measurement
    plt.ylabel(unit)

    # title
    plt.title(title)
    plt.grid(True)

    plt.show()
    
#filter lib
def plotQ(load = None, flt=None):
    if flt is not None and load is not None:
        for key, each in load.items():
            if flt in key:
                #print (key)
                labs = list(each.keys())
                vals = list(each.values())
                #print (labs, vals)
                comp(labels=labs, data=vals, unit='No. of People', title=key)
                #break
    else:
        print ('init load and flt appropriately')
    
#removing punctuation
def remPunc(string=''):
    newstr = string
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    for x in string.lower():
        if x in punctuations:
            newstr = newstr.replace(x,"")
    return newstr
        
'''
for key, each in dist.items():
    #print (key)
    labs = list(each.keys())
    vals = list(each.values())
    #print (labs, vals)
    comp(labels=labs, data=vals, unit='No. of People', title=key)
    #break
        
#comparativeBar()
'''
# Out:
# "\nfor key, each in dist.items():\n    #print (key)\n    labs = list(each.keys())\n    vals = list(each.values())\n    #print (labs, vals)\n    comp(labels=labs, data=vals, unit='No. of People', title=key)\n    #break\n        \n#comparativeBar()\n"

# %%
plotQ(dist, 'Q1.')

# %%
plotQ(dist, 'Q3.')

# %%
plotQ(dist, 'Q7.')

# %%
plotQ(dist, 'Q8.')

# %%
plotQ(dist, 'Q10.')

# %%
#finding and ranking utility Apps
# print(cols)
apps = data.loc[data[cols[1]] == "Africa", cols[6]].tolist()
#print (apps)
appFreq = {}
words = []


for each in apps:
    #print (each)
    #print (type(each))
    if each is 'None' or each is None or each is 'nan' or isinstance(each, float) or isinstance(each, int):
        tmp = ['gabage']
    elif "\n" in each:
        tmp = each.split('\n')
        #print (tmp)
    elif "," in each:
        tmp = each.split(',')
        #print (tmp)
        
    #load apps
    for ap in tmp:
        s = ap.strip()
        if s not in appFreq.keys():
            appFreq[s] = 1
        else:
            appFreq[s] += 1
            
    #secondary filter
    for ap in tmp:
        #print (ap)
        s = ap.strip()
        #print (type(s))
        #print(s)
        if "\n" in s:
            tmps = s.split('\n')            
        elif "," in s:
            tmps = s.split(',')
        else:
            tmps = None
            
        if tmps is None:
            tmps = s.split(' ')
            for sth in tmps:
                words.append(sth.lower())
        else:
            for sth in tmps:
                x = sth.split(' ')
                for sthh in x:
                    words.append(sthh.lower())
            

wordFreq = {}
exclude = ['app', '']
for each in words:
    if each is not "":
        #removing punctuation and evaluation
        tmp = remPunc(each)
        match = None
        
        for every in wordFreq.keys():
            if op(every, each, 0.7) is True:
                match = every
                   
        if match is None:
            if tmp in wordFreq:
                wordFreq[tmp] += 1
            else:
                wordFreq[tmp] = 1
        else:
            wordFreq[match] += 1
        
print(len(wordFreq))

order = sorted(wordFreq.items(), key=operator.itemgetter(1))
order
# Out:
# 73
# [('ntsa', 1),
#  ('chatting', 1),
#  ('finery', 1),
#  ('ebay', 1),
#  ('shopstyle', 1),
#  ('poshmark', 1),
#  ('zara', 1),
#  ('loans', 1),
#  ('2', 1),
#  ('senti', 1),
#  ('chrome', 1),
#  ('uba', 1),
#  ('messages', 1),
#  ('swvl', 1),
#  ('scrabble', 1),
#  ('bolt', 1),
#  ('fpl', 1),
#  ('cba', 2),
#  ('programming', 2),
#  ('phone', 2),
#  ('kilimall', 2),
#  ('mshwari', 2),
#  ('chipper', 2),
#  ('those', 2),
#  ('two', 2),
#  ('airtel', 2),
#  ('sidian', 2),
#  ('news', 2),
#  ('twitter', 2),
#  ('nic', 2),
#  ('my', 2),
#  ('cut', 2),
#  ('apk', 2),
#  ('viusasa', 2),
#  ('gmail', 3),
#  ('okash', 3),
#  ('timiza', 3),
#  ('shopping', 3),
#  ('maps', 3),
#  ('play', 3),
#  ('paste', 3),
#  ('alibaba', 3),
#  ('loop', 4),
#  ('boda', 4),
#  ('wish', 4),
#  ('killmall', 4),
#  ('care', 4),
#  ('aliexpress', 4),
#  ('amazoncom', 5),
#  ('and', 5),
#  ('google', 5),
#  ('up', 6),
#  ('mpesa', 6),
#  ('boomerang', 6),
#  ('store', 6),
#  ('youtube', 7),
#  ('tala', 7),
#  ('ubber', 7),
#  ('instagram', 8),
#  ('barclays', 8),
#  ('branch', 9),
#  ('mobile', 10),
#  ('eazzy', 10),
#  ('online', 11),
#  ('whats', 12),
#  ('kcb', 14),
#  ('equity', 15),
#  ('coop', 15),
#  ('safaricom', 23),
#  ('banking', 25),
#  ('gabage', 25),
#  ('jumia', 28),
#  ('app', 51)]

# %%
apps
# Out:
# ['Safaricom app, kcb app',
#  'Whatsapp \nGmail \nInstagram \nJumia\nCBA LOOP',
#  'Banking App, Programming up',
#  'None',
#  nan,
#  nan,
#  'Browser',
#  'NTSA, equity, co-op bank,safaricom',
#  'Safaricom app\nKCB mobile banking',
#  'Equity,coop,jumia',
#  nan,
#  'Jumia',
#  1,
#  'Instagram, kcb mobile banking, safe boda, YouTube ',
#  'Equity Bank App, Jumia',
#  nan,
#  'Online banking, online chatting apps',
#  'Jumia\nWish\nAmazon.com ',
#  'Online banking, Phone',
#  'None',
#  'Coop bank app, jumia ',
#  'Amazon, finery, thredUp, ebay, shopstyle, poshmark, zara',
#  'Jumia\nKilimall\nFacebook',
#  'Kilimall',
#  "Kcb mpesa\nBarclay's\n",
#  'Eazy banking',
#  'Branch,kcb banking',
#  'Jumia killimall ',
#  'Jumia\nKCB',
#  nan,
#  'Branch,tala,okash,eazzy loans app and kopakash',
#  'Branch, ubapesa, KCB bank app',
#  '1.kcb mobile app\n2. Mpesa app',
#  'Mshwari\nJumia',
#  'Timiza, tala and senti apps',
#  'Jumia \nMobile banking ',
#  0,
#  'Branch,jumuia,safaricom app',
#  'WhatsApp\nChrome\nFacebook\nEquity Mobile banking\nYouTube',
#  'Branch,safaricom app, jumuia',
#  'Jumia, Equity bank app,  chipper cash',
#  'Mpesa,mshwari,kcb,branch,okash,',
#  nan,
#  'Tala\nEquity Ezzy banking app',
#  'Tala\nEquity Ezzy banking app',
#  'Jumia',
#  'Jumia,killmall, only those two online shopping\n',
#  'Ezzy app ',
#  nan,
#  'Safaricom\nAirtel care\nSidian mobile banking\nEazy banking',
#  'Internet Banking ',
#  nan,
#  nan,
#  nan,
#  'Whats app\nInstagram\nGoogle news\nGmail\nBoomerang',
#  'jumia',
#  nan,
#  'Google,Uber,App Store,maps',
#  'Jumia',
#  'Tala',
#  'Santander online, UBA online, FCMB online',
#  'Watsup, Facebook, YouTube, Instagram, Twitter ',
#  'Branch',
#  nan,
#  nan,
#  0,
#  'NIC mobile App\nMCoop App\nJumia App\nKillimall App\nMySafaricom App\nUbber',
#  'NIC mobile App\nMCoop App\nJumia App\nKillimall App\nMySafaricom App\nUbber',
#  nan,
#  'Mobile banking ',
#  'Eazzy app, my safaricom',
#  'KCB App\nMcop Cash\nBarclays Timiza',
#  'WhatsApp,jumia , messages',
#  'Whatsapp\nPlay store',
#  'Whatsapp\nPlay store',
#  'Whatsapp\nPlay store',
#  'Facebook\nWhatsapp',
#  'WhatsApp, Instagram, eazy banking',
#  'MySafaricom \nNCBA Loop\n',
#  'Eazzy Banking App, SWVL, Jumia',
#  'Safaricom app\nEquity\nWish\nSafe boda\nUber',
#  'Twitter ',
#  "I don't use any. I would use a mobile banking app if it was available to me.",
#  'Jumia, AliExpress',
#  nan,
#  'Chipper cash\n',
#  'WhatsApp, Scrabble , Instagram ',
#  'Kcb app\nSafaricom app',
#  'Mobile banking, shopping',
#  'Equity Bank, Amazon, mpesa, ',
#  "Equitel what's up  Facebook instagram telegram ",
#  'Jumia,Bank app,logo creator,cut and paste,Tala apk',
#  'Jumia,Bank app,logo creator,cut and paste,Tala apk',
#  'Safaricom App, Whatsapp,Facebook,',
#  'Jumia',
#  'Mobile banking',
#  'Jumia, equity, viusasa',
#  'Jumia',
#  nan,
#  0,
#  'Mcoop cash, safaricom app, jumia, kcb app, bolt, uber',
#  'Uber, FPL, Play-store ',
#  'Jumia, Alibaba, Aliexpress',
#  'AliExpress',
#  'Safaricom app',
#  nan,
#  'Mobile banking',
#  'Eazzy banking\nTimiza Barclays']

# %%
       
st = 'wellington'
st1 = 'wellton'

op(st, st1)
op(st, 'ezzy')
op('choice', 'choosing')
op('choose', 'choosing')
print (op('flx', 'flex'))

# %%
# !python3 -m spacy download en
data[cols[0]].count()

newD = data.loc[data[cols[1]] == "Africa"]
newD = newD.loc[newD[cols[8]] == "1GB to 3GB"]
newD
# Out:
#                   Timestamp  \
# 0   2019-10-15 07:45:12.875
# 3   2019-10-16 06:14:36.755
# 5   2019-10-16 06:48:37.714
# 12  2019-10-16 09:15:58.534
# 16  2019-10-16 10:10:37.861
# 26  2019-10-16 21:46:25.285
# 29  2019-10-17 05:10:22.950
# 36  2019-10-17 05:50:28.726
# 37  2019-10-17 06:07:38.992
# 39  2019-10-17 06:20:00.100
# 42  2019-10-17 06:27:06.671
# 54  2019-10-17 07:00:37.323
# 55  2019-10-17 07:01:43.096
# 56  2019-10-17 07:05:53.142
# 57  2019-10-17 07:12:15.900
# 68  2019-10-17 08:17:11.009
# 74  2019-10-17 09:33:53.388
# 78  2019-10-17 09:46:38.772
# 82  2019-10-17 10:57:11.030
# 85  2019-10-17 11:25:17.002
# 90  2019-10-17 12:07:33.537
# 104 2019-10-17 18:35:37.345
# 118 2019-10-18 13:20:38.567
# 124 2019-10-18 14:28:54.744
# 127 2019-10-18 17:34:47.103
#
#     Q1. Please choose the closest market region that applies to you?  \
# 0                                               Africa
# 3                                               Africa
# 5                                               Africa
# 12                                              Africa
# 16                                              Africa
# 26                                              Africa
# 29                                              Africa
# 36                                              Africa
# 37                                              Africa
# 39                                              Africa
# 42                                              Africa
# 54                                              Africa
# 55                                              Africa
# 56                                              Africa
# 57                                              Africa
# 68                                              Africa
# 74                                              Africa
# 78                                              Africa
# 82                                              Africa
# 85                                              Africa
# 90                                              Africa
# 104                                             Africa
# 118                                             Africa
# 124                                             Africa
# 127                                             Africa
#
#      Q2. How many devices do you acquire mobile data for?  \
# 0                                                    2
# 3                                                    2
# 5                                                    3
# 12                                                   2
# 16                                                   3
# 26                                                   2
# 29                                                   2
# 36                                                   2
# 37                                                   3
# 39                                                   1
# 42                                                   1
# 54                                                   8
# 55                                                   1
# 56                                                   8
# 57                                                   1
# 68                                                   1
# 74                                                   2
# 78                                                   4
# 82                                                   1
# 85                                                   3
# 90                                                   1
# 104                                                  1
# 118                                                  2
# 124                                                  2
# 127                                                  2
#
#     Q3. What is your primary reason for acquiring mobile data?  \
# 0                                     General Browsing
# 3                                     General Browsing
# 5                                     General Browsing
# 12                                        Social Media
# 16   Utility Apps i.e Mobile Banking, Online Shoppi...
# 26   Utility Apps i.e Mobile Banking, Online Shoppi...
# 29                                    General Browsing
# 36   Utility Apps i.e Mobile Banking, Online Shoppi...
# 37   Utility Apps i.e Mobile Banking, Online Shoppi...
# 39                                        Social Media
# 42                                    General Browsing
# 54                                    General Browsing
# 55                                    General Browsing
# 56                                    General Browsing
# 57   Utility Apps i.e Mobile Banking, Online Shoppi...
# 68                                        Social Media
# 74                                    General Browsing
# 78                                    General Browsing
# 82                                    General Browsing
# 85                                        Social Media
# 90                                    General Browsing
# 104                                   General Browsing
# 118                                   General Browsing
# 124                                   General Browsing
# 127                                       Social Media
#
#      Q4. Roughly how many apps are most used on your device(s)?  \
# 0                                                    9
# 3                                                    5
# 5                                                    5
# 12                                                   6
# 16                                                   5
# 26                                                   3
# 29                                                   5
# 36                                                   6
# 37                                                  50
# 39                                                   3
# 42                                                   7
# 54                                                   5
# 55                                                   5
# 56                                                   7
# 57                                                   5
# 68                                                   5
# 74                                                   3
# 78                                                  15
# 82                                                   5
# 85                                                   7
# 90                                                   5
# 104                                                 10
# 118                                                  7
# 124                                                  3
# 127                                                  5
#
#      Q5. How many of those Apps are Utility Apps such as Mobile Banking, Online shopping?  \
# 0                                                    3
# 3                                                    2
# 5                                                    2
# 12                                                   0
# 16                                                   4
# 26                                                   2
# 29                                                   0
# 36                                                   2
# 37                                                  15
# 39                                                   1
# 42                                                   4
# 54                                                   2
# 55                                                   1
# 56                                                   4
# 57                                                   3
# 68                                                   1
# 74                                                   3
# 78                                                   1
# 82                                                   1
# 85                                                   3
# 90                                                   1
# 104                                                  3
# 118                                                  3
# 124                                                  1
# 127                                                  1
#
#     Q6. Please list some of the Utility Apps, for the previous question Q5, that you frequently use? Try to rank them starting with the most important.  \
# 0                               Safaricom app, kcb app
# 3                          Banking App, Programming up
# 5                                                  NaN
# 12                                                 NaN
# 16   Instagram, kcb mobile banking, safe boda, YouT...
# 26                               Online banking, Phone
# 29                                                None
# 36                               Coop bank app, jumia
# 37   Amazon, finery, thredUp, ebay, shopstyle, posh...
# 39                                            Kilimall
# 42                                  Branch,kcb banking
# 54                         Branch,jumuia,safaricom app
# 55   WhatsApp\nChrome\nFacebook\nEquity Mobile bank...
# 56                        Branch,safaricom app, jumuia
# 57               Jumia, Equity bank app,  chipper cash
# 68                                   Internet Banking
# 74                                                 NaN
# 78           Santander online, UBA online, FCMB online
# 82                                              Branch
# 85                                                 NaN
# 90                                                 NaN
# 104                          MySafaricom \nNCBA Loop\n
# 118                       Equity Bank, Amazon, mpesa,
# 124                                     Mobile banking
# 127                                              Jumia
#
#     Q7. How often do you reload/renew your mobile data plan?  \
# 0                                            Irregular
# 3                                                Daily
# 5                                                Daily
# 12                                           Irregular
# 16                                             Monthly
# 26                                             Monthly
# 29                                               Daily
# 36                                              Weekly
# 37                                               Daily
# 39                                               Daily
# 42                                             Monthly
# 54                                               Daily
# 55                                              Weekly
# 56                                               Daily
# 57                                              Weekly
# 68                                             Monthly
# 74                                               Daily
# 78                                             Monthly
# 82                                               Daily
# 85                                               Daily
# 90                                               Daily
# 104                                             Weekly
# 118                                            Monthly
# 124                                              Daily
# 127                                            Monthly
#
#     Q8. Select the Quantity of data mostly acquire for the period selected in the previous question, Q7?  \
# 0                                           1GB to 3GB
# 3                                           1GB to 3GB
# 5                                           1GB to 3GB
# 12                                          1GB to 3GB
# 16                                          1GB to 3GB
# 26                                          1GB to 3GB
# 29                                          1GB to 3GB
# 36                                          1GB to 3GB
# 37                                          1GB to 3GB
# 39                                          1GB to 3GB
# 42                                          1GB to 3GB
# 54                                          1GB to 3GB
# 55                                          1GB to 3GB
# 56                                          1GB to 3GB
# 57                                          1GB to 3GB
# 68                                          1GB to 3GB
# 74                                          1GB to 3GB
# 78                                          1GB to 3GB
# 82                                          1GB to 3GB
# 85                                          1GB to 3GB
# 90                                          1GB to 3GB
# 104                                         1GB to 3GB
# 118                                         1GB to 3GB
# 124                                         1GB to 3GB
# 127                                         1GB to 3GB
#
#      Q9. How long in days does the acquired data bundle roughly last i.e. before depletion?  \
# 0                                                 28.0
# 3                                                  1.0
# 5                                                  2.0
# 12                                                 3.0
# 16                                                20.0
# 26                                                25.0
# 29                                                 1.0
# 36                                                 5.0
# 37                                                 1.0
# 39                                                 1.0
# 42                                                28.0
# 54                                                 1.0
# 55                                                 7.0
# 56                                                 1.0
# 57                                                 7.0
# 68                                                20.0
# 74                                                 2.0
# 78                                                26.0
# 82                                                 2.0
# 85                                                 1.0
# 90                                              2300.0
# 104                                                3.0
# 118                                               30.0
# 124                                                1.0
# 127                                               30.0
#
#     Q10. How long does it take before reloading your mobile data plan after depletion?
# 0                                         Several Days
# 3                             Automatic reload 0 hours
# 5                             Automatic reload 0 hours
# 12                                               A day
# 16                                        Several Days
# 26                                        Several Days
# 29                                               A day
# 36                            Automatic reload 0 hours
# 37                            Automatic reload 0 hours
# 39                                               A day
# 42                                        Several Days
# 54                            Automatic reload 0 hours
# 55                                         A few Hours
# 56                                         A few Hours
# 57                                               A day
# 68                                        Several Days
# 74                                               A day
# 78                                         A few Hours
# 82                                         A few Hours
# 85                            Automatic reload 0 hours
# 90                            Automatic reload 0 hours
# 104                                        A few Hours
# 118                                        A few Hours
# 124                                        A few Hours
# 127                                        A few Hours

# %%
dataFilter(newD, cols)
# Out:
# {'Q1. Please choose the closest market region that applies to you?': {'Africa': 25},
#  'Q3. What is your primary reason for acquiring mobile data?': {'General Browsing': 15,
#   'Social Media': 5,
#   'Utility Apps i.e Mobile Banking, Online Shopping, etc': 5},
#  'Q7. How often do you reload/renew your mobile data plan?': {'Irregular': 2,
#   'Daily': 12,
#   'Monthly': 7,
#   'Weekly': 4},
#  'Q8. Select the Quantity of data mostly acquire for the period selected in the previous question, Q7?': {'1GB to 3GB': 25},
#  'Q10. How long does it take before reloading your mobile data plan after depletion?': {'Several Days': 5,
#   'Automatic reload 0 hours': 7,
#   'A day': 5,
#   'A few Hours': 8}}

# %%
plotQ(dataFilter(newD, cols), 'Q10.')

# %%
plotQ(dataFilter(newD, cols), 'Q7.')
